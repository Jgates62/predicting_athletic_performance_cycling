# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/gc_data/2019_04_09_22_21_05.csv')

# %%
df.head()
# Out:
#    secs  km  power  hr  cad    alt
# 0     0   0     95  96   80  699.4
# 1     1   0     99  97   83  699.6
# 2     2   0    125  96   86  699.6
# 3     3   0    191  96   90  700.0
# 4     4   0    230  97   90  700.0

# %%
df.shape
# Out:
# (2703, 6)

# %%
df = df.rolling(20).mean();    # 20 sec rolling average

# %%
# Plot the data
sns.set_style('darkgrid')

plt.figure(figsize = (16, 6))
plt.title('Heart Rate, Power * 0.5, Cadence', fontsize= 14)


x = df['secs']

ya = df['hr']
yb = df['power'] * 0.5
yc = df['cad']

plt.plot(x, ya, c = 'tab:red', label= 'Heart Rate (bpm)')
plt.plot(x, yb, c = 'tab:blue', label= 'Power (watts * 0.5)')
plt.plot(x, yc, c = 'tab:green', label= 'Pedaling Cadence (cycles/minute)')

plt.ylim(75, 180)

plt.legend();
