# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
# Use for conda env:tfkGPU - otherwise comment out
import tensorflow as tf
configuration = tf.compat.v1.ConfigProto()
configuration.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=configuration)

# %%
df1_inc = pd.read_csv('../data/data_int/sbj_1_incremental.csv')
df1_inc.head()
# Out:
#    time  Power    Oxygen  Cadence    HR    RF
# 0     3    0.0  602.0000      0.0  86.0  16.0
# 1     4    0.0  578.1250      0.0  86.0  16.0
# 2     5    0.0  558.7500      0.0  86.0  16.0
# 3     6    0.0  542.1875      0.0  86.0  16.0
# 4     7    0.0  527.5000      0.0  86.0  16.0

# %%
df1_inc = df1_inc.iloc[450:2350]
df1_inc
# Out:
#       time  Power       Oxygen  Cadence          HR         RF
# 450    453    0.0   914.716667     90.0   94.016667  16.058333
# 451    454    0.0   859.850000     90.0   93.650000  16.700000
# 452    455    0.0   799.350000     90.0   93.250000  17.600000
# 453    456    0.0   758.325000     90.0   92.858333  18.350000
# 454    457    0.0   736.775000     90.0   92.475000  18.950000
# ...    ...    ...          ...      ...         ...        ...
# 2345  2348   38.0  4162.400000      9.0  171.000000  51.500000
# 2346  2349    0.0  4081.600000      0.0  171.000000  51.100000
# 2347  2350    0.0  4000.100000      0.0  171.100000  50.600000
# 2348  2351    0.0  3968.250000      0.0  171.300000  50.800000
# 2349  2352    0.0  3980.450000      0.0  171.500000  52.100000
#
# [1900 rows x 6 columns]

# %%
# df1_win = pd.read_csv('../data/data_int/sbj_1_Wingate.csv')
# df1_win

# %%
# df1_t1 = pd.read_csv('../data/data_int/sbj_1_I.csv')
# df1_t1

# %%
# df1_t2 = pd.read_csv('../data/data_int/sbj_1_II.csv')
# df1_t2

# %% [markdown]
# ## Data Cleaning

# %%
# Check data types
print(df1_inc.dtypes)
# print(df1_win.dtypes)
# print(df1_t1.dtypes)
# print(df1_t2.dtypes)
# Out:
# time         int64
# Power      float64
# Oxygen     float64
# Cadence    float64
# HR         float64
# RF         float64
# dtype: object

# %%
# Check for nulls
print(df1_inc.isnull().sum())
# print(df1_win.isnull().sum())
# print(df1_t1.isnull().sum())
# print(df1_t2.isnull().sum())
# Out:
# time       0
# Power      0
# Oxygen     0
# Cadence    0
# HR         0
# RF         0
# dtype: int64

# %%
# Lets look at the df1_inc dataframe, and use HR as the target column
# Try to predict heart rate using all the other features - the goal is to be able to tell when you are putting out enough power to
# make yourself go over your target heart rate. This way you could make sure to keep your power under that threshold.
# Also, if you can look at some data sets with longer (2hr+) training sessions, it would be cool to see how fatigue
# Affects the relationship between power and heart rate.

# %%
# Set time as the index for df1_inc
#df1_inc.set_index('time', inplace = True)

# %%
# There is definitely a trend (The test keeps getting harder!)
df1_inc['HR'].plot();

# %%
# Add a negligible amount to columns that contain 0 values in order to prevent NaNs when using pct_change
df1_inc['Power'] = df1_inc['Power'] + 0.0001
df1_inc['Cadence'] = df1_inc['Cadence'] + 0.0001

# Set 'time' as the index
df1_inc.set_index('time', inplace= True)

# This should get rid of trend
hr_changes = df1_inc.pct_change()

# %%
hr_changes['HR'].plot();

# %% [markdown]
# ### Train, Test, Split, and Modeling

# %%
df1_inc
# Out:
#         Power       Oxygen  Cadence          HR         RF
# time
# 453    0.0001   914.716667  90.0001   94.016667  16.058333
# 454    0.0001   859.850000  90.0001   93.650000  16.700000
# 455    0.0001   799.350000  90.0001   93.250000  17.600000
# 456    0.0001   758.325000  90.0001   92.858333  18.350000
# 457    0.0001   736.775000  90.0001   92.475000  18.950000
# ...       ...          ...      ...         ...        ...
# 2348  38.0001  4162.400000   9.0001  171.000000  51.500000
# 2349   0.0001  4081.600000   0.0001  171.000000  51.100000
# 2350   0.0001  4000.100000   0.0001  171.100000  50.600000
# 2351   0.0001  3968.250000   0.0001  171.300000  50.800000
# 2352   0.0001  3980.450000   0.0001  171.500000  52.100000
#
# [1900 rows x 5 columns]

# %%
hr_changes
# Out:
#          Power    Oxygen   Cadence        HR        RF
# time
# 453        NaN       NaN       NaN       NaN       NaN
# 454   0.000000 -0.059982  0.000000 -0.003900  0.039958
# 455   0.000000 -0.070361  0.000000 -0.004271  0.053892
# 456   0.000000 -0.051323  0.000000 -0.004200  0.042614
# 457   0.000000 -0.028418  0.000000 -0.004128  0.032698
# ...        ...       ...       ...       ...       ...
# 2348 -0.499999 -0.003149 -0.499997  0.000000  0.003899
# 2349 -0.999997 -0.019412 -0.999989  0.000000 -0.007767
# 2350  0.000000 -0.019968  0.000000  0.000585 -0.009785
# 2351  0.000000 -0.007962  0.000000  0.001169  0.003953
# 2352  0.000000  0.003074  0.000000  0.001168  0.025591
#
# [1900 rows x 5 columns]

# %%
hr_changes.dtypes
# Out:
# Power      float64
# Oxygen     float64
# Cadence    float64
# HR         float64
# RF         float64
# dtype: object

# %%
hr_changes.isnull().sum()
# Out:
# Power      1
# Oxygen     1
# Cadence    1
# HR         1
# RF         1
# dtype: int64

# %%
hr_changes.dropna(inplace= True)

# %%
# Create X and y
X = df1_inc.drop(columns= ['HR'])
y = df1_inc['HR'].values

# %%
X
# Out:
#         Power       Oxygen  Cadence         RF
# time
# 453    0.0001   914.716667  90.0001  16.058333
# 454    0.0001   859.850000  90.0001  16.700000
# 455    0.0001   799.350000  90.0001  17.600000
# 456    0.0001   758.325000  90.0001  18.350000
# 457    0.0001   736.775000  90.0001  18.950000
# ...       ...          ...      ...        ...
# 2348  38.0001  4162.400000   9.0001  51.500000
# 2349   0.0001  4081.600000   0.0001  51.100000
# 2350   0.0001  4000.100000   0.0001  50.600000
# 2351   0.0001  3968.250000   0.0001  50.800000
# 2352   0.0001  3980.450000   0.0001  52.100000
#
# [1900 rows x 4 columns]

# %%
# Train/Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle= False)

# %%
X_train
# Out:
#          Power       Oxygen  Cadence         RF
# time
# 453     0.0001   914.716667  90.0001  16.058333
# 454     0.0001   859.850000  90.0001  16.700000
# 455     0.0001   799.350000  90.0001  17.600000
# 456     0.0001   758.325000  90.0001  18.350000
# 457     0.0001   736.775000  90.0001  18.950000
# ...        ...          ...      ...        ...
# 1873  300.0001  3804.100000  90.0001  36.600000
# 1874  300.0001  3799.700000  90.0001  35.900000
# 1875  300.0001  3767.416667  90.0001  35.083333
# 1876  300.0001  3707.250000  90.0001  34.150000
# 1877  300.0001  3670.600000  90.0001  33.400000
#
# [1425 rows x 4 columns]

# %%
# Scale
ss = StandardScaler()
Z_train = ss.fit_transform(X_train)
Z_test = ss.fit_transform(X_test)

# %%
# Create training sequences
train_sequences = TimeseriesGenerator(Z_train, y_train, length=3, batch_size=32)

# Create test sequences
test_sequences = TimeseriesGenerator(Z_test, y_test, length=3, batch_size=32)

# %%
train_sequences[0][0].shape
# Out:
# (32, 3, 4)

# %%
train_sequences[1][0].shape # shape of first batch
# Out:
# (32, 3, 4)

# %%
train_sequences[0][1] # y first batch
# Out:
# array([92.85833333, 92.475     , 92.1       , 91.76666667, 91.4       ,
#        91.        , 90.525     , 90.00833333, 89.45      , 88.85      ,
#        88.29166667, 87.775     , 87.3       , 86.83333333, 86.46666667,
#        86.2       , 86.075     , 86.05833333, 86.15      , 86.35      ,
#        86.475     , 86.525     , 86.5       , 86.55      , 86.58333333,
#        86.6       , 86.6       , 86.56666667, 86.5       , 86.4       ,
#        86.4       , 86.46666667])

# %%
train_sequences[1][1] # y second batch
# Out:
# array([86.6       , 86.65      , 86.575     , 86.375     , 86.05      ,
#        85.65      , 85.17      , 84.61      , 83.97      , 83.28333333,
#        82.55      , 81.75      , 80.925     , 80.275     , 79.8       ,
#        79.5       , 79.34666667, 79.34      , 79.48      , 79.83333333,
#        80.4       , 81.2       , 82.33333333, 83.6       , 85.        ,
#        86.3       , 87.53333333, 88.7       , 89.85      , 90.91666667,
#        92.01666667, 93.15      ])

# %%
# RNN Design

model = Sequential()

model.add(GRU(4, input_shape=(3, 4), return_sequences=True)) # True if the next layer is RNN
model.add(GRU(4, return_sequences=False)) # False if the next layer is Dense
model.add(Dense(4, activation='relu'))
# output layer for binary classification
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='mse', optimizer=Adam(lr=.0005), metrics= 'mse')

# %%
res = model.fit(train_sequences, 
                epochs=100, 
                validation_data=test_sequences, 
                shuffle= False,
                #callbacks = [early_stopping]
               )
# Out:
# Epoch 1/100
# 45/45 [==============================] - 1s 16ms/step - loss: 17544.5371 - mse: 17544.5371 - val_loss: 29035.1016 - val_mse: 29035.1016
# Epoch 2/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17536.0371 - mse: 17536.0371 - val_loss: 29024.4512 - val_mse: 29024.4512
# Epoch 3/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17527.0312 - mse: 17527.0312 - val_loss: 29010.8027 - val_mse: 29010.8027
# Epoch 4/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17515.0117 - mse: 17515.0117 - val_loss: 28993.0254 - val_mse: 28993.0254
# Epoch 5/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17500.2676 - mse: 17500.2676 - val_loss: 28970.7559 - val_mse: 28970.7559
# Epoch 6/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17482.4453 - mse: 17482.4453 - val_loss: 28947.1445 - val_mse: 28947.1445
# Epoch 7/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17465.0449 - mse: 17465.0449 - val_loss: 28926.2266 - val_mse: 28926.2266
# Epoch 8/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17450.8711 - mse: 17450.8711 - val_loss: 28910.7949 - val_mse: 28910.7949
# Epoch 9/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17441.1719 - mse: 17441.1719 - val_loss: 28900.5254 - val_mse: 28900.5254
# Epoch 10/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17435.0391 - mse: 17435.0391 - val_loss: 28893.8516 - val_mse: 28893.8516
# Epoch 11/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17431.1387 - mse: 17431.1387 - val_loss: 28889.4082 - val_mse: 28889.4082
# Epoch 12/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17428.5664 - mse: 17428.5664 - val_loss: 28886.3516 - val_mse: 28886.3516
# Epoch 13/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17426.7969 - mse: 17426.7969 - val_loss: 28884.1660 - val_mse: 28884.1660
# Epoch 14/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17425.5254 - mse: 17425.5254 - val_loss: 28882.5508 - val_mse: 28882.5508
# Epoch 15/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17424.5801 - mse: 17424.5801 - val_loss: 28881.3203 - val_mse: 28881.3203
# Epoch 16/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17423.8555 - mse: 17423.8555 - val_loss: 28880.3652 - val_mse: 28880.3652
# Epoch 17/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17423.2910 - mse: 17423.2910 - val_loss: 28879.5996 - val_mse: 28879.5996
# Epoch 18/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17422.8340 - mse: 17422.8340 - val_loss: 28878.9785 - val_mse: 28878.9785
# Epoch 19/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17422.4629 - mse: 17422.4629 - val_loss: 28878.4688 - val_mse: 28878.4688
# Epoch 20/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17422.1523 - mse: 17422.1523 - val_loss: 28878.0449 - val_mse: 28878.0449
# Epoch 21/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17421.8965 - mse: 17421.8965 - val_loss: 28877.6836 - val_mse: 28877.6836
# Epoch 22/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17421.6719 - mse: 17421.6719 - val_loss: 28877.3770 - val_mse: 28877.3770
# Epoch 23/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17421.4824 - mse: 17421.4824 - val_loss: 28877.1094 - val_mse: 28877.1094
# Epoch 24/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17421.3184 - mse: 17421.3184 - val_loss: 28876.8828 - val_mse: 28876.8828
# Epoch 25/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17421.1758 - mse: 17421.1758 - val_loss: 28876.6836 - val_mse: 28876.6836
# Epoch 26/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17421.0527 - mse: 17421.0527 - val_loss: 28876.5059 - val_mse: 28876.5059
# Epoch 27/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17420.9375 - mse: 17420.9375 - val_loss: 28876.3477 - val_mse: 28876.3477
# Epoch 28/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17420.8418 - mse: 17420.8418 - val_loss: 28876.2090 - val_mse: 28876.2090
# Epoch 29/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17420.7559 - mse: 17420.7559 - val_loss: 28876.0801 - val_mse: 28876.0801
# Epoch 30/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17420.6758 - mse: 17420.6758 - val_loss: 28875.9727 - val_mse: 28875.9727
# Epoch 31/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17420.6055 - mse: 17420.6055 - val_loss: 28875.8691 - val_mse: 28875.8691
# Epoch 32/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17420.5410 - mse: 17420.5410 - val_loss: 28875.7793 - val_mse: 28875.7793
# Epoch 33/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17420.4805 - mse: 17420.4805 - val_loss: 28875.6953 - val_mse: 28875.6953
# Epoch 34/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17420.4258 - mse: 17420.4258 - val_loss: 28875.6211 - val_mse: 28875.6211
# Epoch 35/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17420.3789 - mse: 17420.3789 - val_loss: 28875.5488 - val_mse: 28875.5488
# Epoch 36/100
# 45/45 [==============================] - 0s 7ms/step - loss: 17420.3320 - mse: 17420.3320 - val_loss: 28875.4863 - val_mse: 28875.4863
# Epoch 37/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17420.2949 - mse: 17420.2949 - val_loss: 28875.4297 - val_mse: 28875.4297
# Epoch 38/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17420.2539 - mse: 17420.2539 - val_loss: 28875.3730 - val_mse: 28875.3730
# Epoch 39/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17420.2188 - mse: 17420.2188 - val_loss: 28875.3242 - val_mse: 28875.3242
# Epoch 40/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17420.1895 - mse: 17420.1895 - val_loss: 28875.2793 - val_mse: 28875.2793
# Epoch 41/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17420.1582 - mse: 17420.1582 - val_loss: 28875.2402 - val_mse: 28875.2402
# Epoch 42/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17420.1309 - mse: 17420.1309 - val_loss: 28875.1953 - val_mse: 28875.1953
# Epoch 43/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17420.1035 - mse: 17420.1035 - val_loss: 28875.1582 - val_mse: 28875.1582
# Epoch 44/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17420.0801 - mse: 17420.0801 - val_loss: 28875.1250 - val_mse: 28875.1250
# Epoch 45/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17420.0586 - mse: 17420.0586 - val_loss: 28875.0938 - val_mse: 28875.0938
# Epoch 46/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17420.0352 - mse: 17420.0352 - val_loss: 28875.0605 - val_mse: 28875.0605
# Epoch 47/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17420.0137 - mse: 17420.0137 - val_loss: 28875.0391 - val_mse: 28875.0391
# Epoch 48/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.9980 - mse: 17419.9980 - val_loss: 28875.0078 - val_mse: 28875.0078
# Epoch 49/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.9785 - mse: 17419.9785 - val_loss: 28874.9863 - val_mse: 28874.9863
# Epoch 50/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.9629 - mse: 17419.9629 - val_loss: 28874.9590 - val_mse: 28874.9590
# Epoch 51/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.9492 - mse: 17419.9492 - val_loss: 28874.9355 - val_mse: 28874.9355
# Epoch 52/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.9375 - mse: 17419.9375 - val_loss: 28874.9199 - val_mse: 28874.9199
# Epoch 53/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.9219 - mse: 17419.9219 - val_loss: 28874.9023 - val_mse: 28874.9023
# Epoch 54/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.9062 - mse: 17419.9062 - val_loss: 28874.8828 - val_mse: 28874.8828
# Epoch 55/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.8965 - mse: 17419.8965 - val_loss: 28874.8652 - val_mse: 28874.8652
# Epoch 56/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.8848 - mse: 17419.8848 - val_loss: 28874.8457 - val_mse: 28874.8457
# Epoch 57/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.8711 - mse: 17419.8711 - val_loss: 28874.8320 - val_mse: 28874.8320
# Epoch 58/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.8613 - mse: 17419.8613 - val_loss: 28874.8164 - val_mse: 28874.8164
# Epoch 59/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.8496 - mse: 17419.8496 - val_loss: 28874.8027 - val_mse: 28874.8027
# Epoch 60/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.8438 - mse: 17419.8438 - val_loss: 28874.7910 - val_mse: 28874.7910
# Epoch 61/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.8359 - mse: 17419.8359 - val_loss: 28874.7754 - val_mse: 28874.7754
# Epoch 62/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.8281 - mse: 17419.8281 - val_loss: 28874.7656 - val_mse: 28874.7656
# Epoch 63/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.8184 - mse: 17419.8184 - val_loss: 28874.7520 - val_mse: 28874.7520
# Epoch 64/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.8125 - mse: 17419.8125 - val_loss: 28874.7441 - val_mse: 28874.7441
# Epoch 65/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.8008 - mse: 17419.8008 - val_loss: 28874.7344 - val_mse: 28874.7344
# Epoch 66/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.7969 - mse: 17419.7969 - val_loss: 28874.7246 - val_mse: 28874.7246
# Epoch 67/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.7910 - mse: 17419.7910 - val_loss: 28874.7109 - val_mse: 28874.7109
# Epoch 68/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.7832 - mse: 17419.7832 - val_loss: 28874.7070 - val_mse: 28874.7070
# Epoch 69/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.7773 - mse: 17419.7773 - val_loss: 28874.6953 - val_mse: 28874.6953
# Epoch 70/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7695 - mse: 17419.7695 - val_loss: 28874.6855 - val_mse: 28874.6855
# Epoch 71/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7656 - mse: 17419.7656 - val_loss: 28874.6816 - val_mse: 28874.6816
# Epoch 72/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7617 - mse: 17419.7617 - val_loss: 28874.6758 - val_mse: 28874.6758
# Epoch 73/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7559 - mse: 17419.7559 - val_loss: 28874.6660 - val_mse: 28874.6660
# Epoch 74/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7500 - mse: 17419.7500 - val_loss: 28874.6582 - val_mse: 28874.6582
# Epoch 75/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7441 - mse: 17419.7441 - val_loss: 28874.6504 - val_mse: 28874.6504
# Epoch 76/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.7402 - mse: 17419.7402 - val_loss: 28874.6484 - val_mse: 28874.6484
# Epoch 77/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7383 - mse: 17419.7383 - val_loss: 28874.6406 - val_mse: 28874.6406
# Epoch 78/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7344 - mse: 17419.7344 - val_loss: 28874.6348 - val_mse: 28874.6348
# Epoch 79/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7305 - mse: 17419.7305 - val_loss: 28874.6270 - val_mse: 28874.6270
# Epoch 80/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.7266 - mse: 17419.7266 - val_loss: 28874.6230 - val_mse: 28874.6230
# Epoch 81/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.7227 - mse: 17419.7227 - val_loss: 28874.6191 - val_mse: 28874.6191
# Epoch 82/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7168 - mse: 17419.7168 - val_loss: 28874.6152 - val_mse: 28874.6152
# Epoch 83/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7148 - mse: 17419.7148 - val_loss: 28874.6094 - val_mse: 28874.6094
# Epoch 84/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7109 - mse: 17419.7109 - val_loss: 28874.6035 - val_mse: 28874.6035
# Epoch 85/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7109 - mse: 17419.7109 - val_loss: 28874.5977 - val_mse: 28874.5977
# Epoch 86/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7090 - mse: 17419.7090 - val_loss: 28874.5938 - val_mse: 28874.5938
# Epoch 87/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.7051 - mse: 17419.7051 - val_loss: 28874.5918 - val_mse: 28874.5918
# Epoch 88/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.7031 - mse: 17419.7031 - val_loss: 28874.5898 - val_mse: 28874.5898
# Epoch 89/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.6953 - mse: 17419.6953 - val_loss: 28874.5840 - val_mse: 28874.5840
# Epoch 90/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.6953 - mse: 17419.6953 - val_loss: 28874.5781 - val_mse: 28874.5781
# Epoch 91/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.6934 - mse: 17419.6934 - val_loss: 28874.5762 - val_mse: 28874.5762
# Epoch 92/100
# 45/45 [==============================] - 0s 7ms/step - loss: 17419.6914 - mse: 17419.6914 - val_loss: 28874.5742 - val_mse: 28874.5742
# Epoch 93/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.6875 - mse: 17419.6875 - val_loss: 28874.5703 - val_mse: 28874.5703
# Epoch 94/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.6855 - mse: 17419.6855 - val_loss: 28874.5684 - val_mse: 28874.5684
# Epoch 95/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.6836 - mse: 17419.6836 - val_loss: 28874.5645 - val_mse: 28874.5645
# Epoch 96/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.6816 - mse: 17419.6816 - val_loss: 28874.5605 - val_mse: 28874.5605
# Epoch 97/100
# 45/45 [==============================] - 0s 5ms/step - loss: 17419.6816 - mse: 17419.6816 - val_loss: 28874.5586 - val_mse: 28874.5586
# Epoch 98/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.6797 - mse: 17419.6797 - val_loss: 28874.5547 - val_mse: 28874.5547
# Epoch 99/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.6758 - mse: 17419.6758 - val_loss: 28874.5547 - val_mse: 28874.5547
# Epoch 100/100
# 45/45 [==============================] - 0s 6ms/step - loss: 17419.6758 - mse: 17419.6758 - val_loss: 28874.5508 - val_mse: 28874.5508

# %%
plt.plot(res.history['loss'], label= 'Train')
plt.plot(res.history['val_loss'], label= 'Test')
#plt.ylim(0, .01);

# %%
model.evaluate(test_sequences)
# Out:
# 15/15 [==============================] - 0s 2ms/step - loss: 28874.5508 - mse: 28874.5508
# [28874.55078125, 28874.55078125]

# %%
predictions = model.predict(test_sequences)

# %%
#predictions

# %%
# Train
#r2_score(Z_train[3:], model.predict(train_sequences))

# %%
#model.predict(train_sequences)

# %%
# Test

len(model.predict(test_sequences))
# Out:
# 472

# %%
# y_test_actual = []
# for i in range(len(test_sequences)):
#     x, y = test_sequences[i]
#     for val in y:
#         y_test_actual.append(val)
#     #print(f'x of {i}: {x}')
#     print(f'y of {i}: {y}')
    
# print(len(y_test_actual))

# %%
r2_score(y_test[3:], predictions)
# Out:
# -1639.5622705472117

# %%
preds_df = pd.DataFrame(predictions)
preds_df.head(50)
# Out:
#            0
# 0   0.999799
# 1   0.999800
# 2   0.999800
# 3   0.999799
# 4   0.999798
# 5   0.999796
# 6   0.999795
# 7   0.999793
# 8   0.999791
# 9   0.999789
# 10  0.999787
# 11  0.999784
# 12  0.999782
# 13  0.999781
# 14  0.999783
# 15  0.999785
# 16  0.999787
# 17  0.999788
# 18  0.999789
# 19  0.999790
# 20  0.999792
# 21  0.999793
# 22  0.999795
# 23  0.999797
# 24  0.999798
# 25  0.999799
# 26  0.999799
# 27  0.999799
# 28  0.999798
# 29  0.999797
# 30  0.999797
# 31  0.999797
# 32  0.999797
# 33  0.999796
# 34  0.999796
# 35  0.999795
# 36  0.999796
# 37  0.999797
# 38  0.999798
# 39  0.999799
# 40  0.999799
# 41  0.999800
# 42  0.999800
# 43  0.999800
# 44  0.999799
# 45  0.999798
# 46  0.999797
# 47  0.999796
# 48  0.999795
# 49  0.999794

# %%
# https://www.tutorialguruji.com/python/pandas-how-to-revert-pct_change-to-the-original-value-with-the-initial-value/
preds_df.add(1,fill_value=0).cumprod()
# Out:
#              0
# 0     1.999799
# 1     3.999198
# 2     7.997595
# 3    15.993583
# 4    31.983929
# ..         ...
# 467        inf
# 468        inf
# 469        inf
# 470        inf
# 471        inf
#
# [472 rows x 1 columns]

# %%
pd.DataFrame(y_test[3:])
# Out:
#          0
# 0    163.8
# 1    163.9
# 2    164.0
# 3    164.0
# 4    164.0
# ..     ...
# 467  171.0
# 468  171.0
# 469  171.1
# 470  171.3
# 471  171.5
#
# [472 rows x 1 columns]

# %%
ss.inverse_transform(preds_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31664/4020009013.py in <module>
# ----> 1 ss.inverse_transform(preds_df)
#
# ~\anaconda3\envs\tfkGPU\lib\site-packages\sklearn\preprocessing\_data.py in inverse_transform(self, X, copy)
#    1033         else:
#    1034             if self.with_std:
# -> 1035                 X *= self.scale_
#    1036             if self.with_mean:
#    1037                 X += self.mean_
#
# ValueError: non-broadcastable output operand with shape (472,1) doesn't match the broadcast shape (472,4)

# %%
# This is the original scaled X_train and X_test data
ss.inverse_transform(Z_train)

# %%
ss.inverse_transform(Z_test)

# %%
# ideas - use a batch size that is the size of your entire df,
