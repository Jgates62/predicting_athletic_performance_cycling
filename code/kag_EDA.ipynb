# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_info = pd.read_csv('../data/data_int/test_subj_info_kag_cycling.csv')
df_info
# Out:
#   Gender   age  weight  height  VO2max  PPO   P1   P2   P3
# 0      M  22.1    67.9   185.0    4650  360  134  286  333
# 1      M  25.6    79.2   182.4    5892  420  144  322  388
# 2      M  42.8    81.9   173.8    4320  318  104  234  287
# 3      F  21.6    66.2   165.9    3693  300   96  219  273
# 4      M  46.6    81.1   181.0    4120  300   96  216  270
# 5      M  28.8    74.4   171.0    4520  347  108  243  308
# 6      M  41.2    81.1   180.5    3912  300   85  206  271

# %%
# PPO : Peak Power Output

# %%
df1_inc = pd.read_csv('../data/data_int/sbj_1_incremental.csv')
df1_inc
# Out:
#       time  Power      Oxygen  Cadence     HR         RF
# 0        3    0.0  602.000000      0.0   86.0  16.000000
# 1        4    0.0  578.125000      0.0   86.0  16.000000
# 2        5    0.0  558.750000      0.0   86.0  16.000000
# 3        6    0.0  542.187500      0.0   86.0  16.000000
# 4        7    0.0  527.500000      0.0   86.0  16.000000
# ...    ...    ...         ...      ...    ...        ...
# 2826  2829    0.0  615.450000      0.0  101.0  22.800000
# 2827  2830    0.0  640.250000      0.0  101.0  23.111111
# 2828  2831    0.0  662.968750      0.0  101.0  23.500000
# 2829  2832    0.0  682.714286      0.0  101.0  24.000000
# 2830  2833    0.0  698.000000      0.0  101.0  24.666667
#
# [2831 rows x 6 columns]

# %%
df_vis = df1_inc['Oxygen'] * 0.1
df_vis
# Out:
# 0       60.200000
# 1       57.812500
# 2       55.875000
# 3       54.218750
# 4       52.750000
#           ...
# 2826    61.545000
# 2827    64.025000
# 2828    66.296875
# 2829    68.271429
# 2830    69.800000
# Name: Oxygen, Length: 2831, dtype: float64

# %%
# Plot the data
sns.set_style('darkgrid')

plt.figure(figsize = (16, 6))
plt.title('Athlete 1 Incremental Test: Heart Rate, Power * 0.5, Cadence', fontsize= 14)


x = df1_inc['time']

ya = df1_inc['HR']
yb = (df1_inc['Power'] * 0.5)
yc = df1_inc['Cadence']

plt.plot(x, ya, c = 'tab:red', label= 'Heart Rate (bpm)')
plt.plot(x, yb, c = 'tab:blue', label= 'Power (watts * 0.5)')
plt.plot(x, yc, c = 'tab:green', label= 'Pedaling Cadence (cycles/minute)')

plt.legend();

# %%
df1_win = pd.read_csv('../data/data_int/sbj_1_Wingate.csv')
df1_win
# Out:
#      time  Power      Oxygen  Cadence          HR         RF
# 0       2    0.0  329.533333      0.0   82.333333  18.400000
# 1       3    0.0  345.333333      0.0   82.000000  18.666667
# 2       4    0.0  361.000000      0.0   81.571429  18.857143
# 3       5    0.0  387.312500      0.0   81.187500  19.312500
# 4       6    0.0  420.722222      0.0   80.833333  19.944444
# ..    ...    ...         ...      ...         ...        ...
# 746   748    0.0  644.350000      0.0  102.900000  30.450000
# 747   749    0.0  698.016667      0.0  102.400000  33.116667
# 748   750    0.0  782.400000      0.0  101.950000  35.750000
# 749   751    0.0  897.500000      0.0  101.550000  38.350000
# 750   752    0.0  866.200000      0.0  101.150000  38.550000
#
# [751 rows x 6 columns]

# %%
# Plot the data
sns.set_style('darkgrid')

plt.figure(figsize = (16, 6))
plt.title('Athlete 1 Wingate Test: Heart Rate, Power * 0.25, Cadence', fontsize= 14)


x = df1_win['time']

ya = df1_win['HR']
yb = (df1_win['Power'] * 0.25)
yc = df1_win['Cadence']

plt.plot(x, ya, c = 'tab:red', label= 'Heart Rate (bpm)')
plt.plot(x, yb, c = 'tab:blue', label= 'Power (watts * 0.25)')
plt.plot(x, yc, c = 'tab:orange', label= 'Pedaling Cadence (cycles/minute)')

plt.legend();

# %%
# # Plot the data
# sns.set_style('darkgrid')

# plt.figure(figsize = (20, 8))

# ax1 = plt.subplot(2, 1, 1, title= 'HR and RF', ylabel= 'HR and RF')
# ax2 = plt.subplot(2, 1, 2, title= 'Power and Oxygen Consumption')

# x = df1_win['time']

# y1 = df1_win['HR']
# y2 = df1_win['RF']

# ya = df1_win['Power'] * 0.25
# yb = (df1_win['HR'])
# yc = df1_win['Cadence']


# ax1.plot(x, y1, c = 'tab:red', label= 'HR')
# ax1.plot(x, y2, c = 'tab:blue', label= 'RF')

# ax2.plot(x, ya, c = 'tab:orange', label= 'Power in Watts * 0.25')
# ax2.plot(x, yb, c = 'tab:red', label= 'HR')
# ax2.plot(x, yc, c = 'tab:brown', label= 'Cadence')

# ax1.legend();
# ax2.legend();

# %%
df1_t1 = pd.read_csv('../data/data_int/sbj_1_I.csv')
df1_t1
# Out:
#       time  Power      Oxygen  Cadence          HR         RF
# 0        1    0.0  318.400000        0   75.600000  20.100000
# 1        2    0.0  356.166667        0   75.666667  19.750000
# 2        3    0.0  403.285714        0   75.714286  19.428571
# 3        4    0.0  456.250000        0   75.750000  19.125000
# 4        5    0.0  478.925926        0   75.740741  18.962963
# ...    ...    ...         ...      ...         ...        ...
# 2814  2815    0.0  629.300000        0  106.350000  23.500000
# 2815  2816    0.0  625.888889        0  106.166667  23.555556
# 2816  2817    0.0  608.125000        0  105.937500  24.000000
# 2817  2818    0.0  596.476191        0  105.785714  24.380952
# 2818  2819    0.0  594.000000        0  105.750000  24.666667
#
# [2819 rows x 6 columns]

# %%
# Plot the data
sns.set_style('darkgrid')

plt.figure(figsize = (16, 6))
plt.title('Athlete 1 Test 1: Heart Rate, Power * 0.5, Cadence', fontsize= 14)

x = df1_t1['time']

ya = df1_t1['HR']
yb = (df1_t1['Power'] * 0.5)
yc = df1_t1['Cadence']

plt.plot(x, ya, c = 'tab:red', label= 'Heart Rate (bpm)')
plt.plot(x, yb, c = 'tab:blue', label= 'Power (watts * 0.5)')
plt.plot(x, yc, c = 'tab:green', label= 'Pedaling Cadence (cycles/minute)')

plt.legend();

# %%
# # Plot the data
# sns.set_style('darkgrid')

# plt.figure(figsize = (20, 8))

# ax1 = plt.subplot(2, 1, 1, title= 'HR and RF', ylabel= 'HR and RF')
# ax2 = plt.subplot(2, 1, 2, title= 'Power and Oxygen Consumption')

# x = df1_t1['time']

# y1 = df1_t1['HR']
# y2 = df1_t1['RF']

# ya = df1_t1['Power'] * 0.5
# yb = (df1_t1['HR'])
# yc = df1_t1['Cadence']


# ax1.plot(x, y1, c = 'tab:red', label= 'HR')
# ax1.plot(x, y2, c = 'tab:blue', label= 'RF')

# ax2.plot(x, ya, c = 'tab:orange', label= 'Power in Watts')
# ax2.plot(x, yb, c = 'teal', label= 'Heart Rate')
# ax2.plot(x, yc, c = 'tab:brown', label= 'Cadence')

# ax1.legend();
# ax2.legend();

# %%
df1_t2 = pd.read_csv('../data/data_int/sbj_1_II.csv')
df1_t2
# Out:
#       time  Power      Oxygen  Cadence         HR         RF
# 0        2    0.0  454.500000      0.0  69.600000  26.300000
# 1        3    0.0  501.583333      0.0  69.500000  25.083333
# 2        4    0.0  524.261905      0.0  69.523810  24.166667
# 3        5    0.0  531.687500      0.0  69.625000  23.437500
# 4        6    0.0  528.944444      0.0  69.777778  22.833333
# ...    ...    ...         ...      ...        ...        ...
# 2574  2576    0.0  471.150000      0.0  80.250000  23.900000
# 2575  2577    0.0  446.833333      0.0  80.500000  23.111111
# 2576  2578    0.0  416.500000      0.0  80.718750  22.656250
# 2577  2579    0.0  377.571429      0.0  80.892857  22.678571
# 2578  2580    0.0  325.750000      0.0  81.000000  23.416667
#
# [2579 rows x 6 columns]

# %%
# Plot the data
sns.set_style('darkgrid')

plt.figure(figsize = (16, 6))
plt.title('Athlete 1 Test 2: Heart Rate, Power * 0.5, Cadence', fontsize= 14)

x = df1_t2['time']

ya = df1_t2['HR']
yb = (df1_t2['Power'] * 0.5)
yc = df1_t2['Cadence']

plt.plot(x, ya, c = 'tab:red', label= 'Heart Rate (bpm)')
plt.plot(x, yb, c = 'tab:blue', label= 'Power (watts * 0.5)')
plt.plot(x, yc, c = 'tab:green', label= 'Pedaling Cadence (cycles/minute)')

plt.legend();

# %%
# # Plot the data
# sns.set_style('darkgrid')

# plt.figure(figsize = (20, 8))

# ax1 = plt.subplot(2, 1, 1, title= 'HR and RF', ylabel= 'HR and RF')
# ax2 = plt.subplot(2, 1, 2, title= 'Power and Oxygen Consumption')

# x = df1_t2['time']

# y1 = df1_t2['HR']
# y2 = df1_t2['RF']

# ya = df1_t2['Power']
# yb = (df1_t2['Oxygen'] * 0.1)
# yc = df1_t2['Cadence']


# ax1.plot(x, y1, c = 'tab:red', label= 'HR')
# ax1.plot(x, y2, c = 'tab:blue', label= 'RF')

# ax2.plot(x, ya, c = 'tab:orange', label= 'Power in Watts')
# ax2.plot(x, yb, c = 'teal', label= 'Oxygen Consumption * 0.1')
# ax2.plot(x, yc, c = 'tab:brown', label= 'Cadence')

# ax1.legend();
# ax2.legend();

# %%
# Use power data from 3 train csv files to predict power output for a different test?
# Use 3 train csv files to predict time to completion for a given event?
# Predict age, weight, or some other person metric by looking at the data from other athletes?
